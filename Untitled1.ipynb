# %%
df_spark = catalog.load("raw_trips_spark")
# Out:
# [02/02/24 13:47:07] INFO     Loading data from raw_trips_spark (SparkDataset)...                ]8;id=486468;file:///home/mark/miniconda3/envs/delta_install/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=785228;file:///home/mark/miniconda3/envs/delta_install/lib/python3.10/site-packages/kedro/io/data_catalog.py#483\483]8;;\

# %%
df_delta = catalog.load("raw_trips_delta")
# Out:
# [02/02/24 13:47:12] INFO     Loading data from raw_trips_delta (DeltaTableDataset)...           ]8;id=437382;file:///home/mark/miniconda3/envs/delta_install/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=636086;file:///home/mark/miniconda3/envs/delta_install/lib/python3.10/site-packages/kedro/io/data_catalog.py#483\483]8;;\
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/mark/miniconda3/envs/delta_install/lib/python3.10/site-packages/kedro/io/core.py:186 in    │
# │ load                                                                                             │
# │                                                                                                  │
# │   183 │   │   self._logger.debug("Loading %s", str(self))                                        │
# │   184 │   │                                                                                      │
# │   185 │   │   try:                                                                               │
# │ ❱ 186 │   │   │   return self._load()                                                            │
# │   187 │   │   except DatasetError:                                                               │
# │   188 │   │   │   raise                                                                          │
# │   189 │   │   except Exception as exc:                                                           │
# │                                                                                                  │
# │ /home/mark/miniconda3/envs/delta_install/lib/python3.10/site-packages/kedro_datasets/spark/delta │
# │ table_dataset.py:87 in _load                                                                     │
# │                                                                                                  │
# │    84 │                                                                                          │
# │    85 │   def _load(self) -> DeltaTable:                                                         │
# │    86 │   │   load_path = self._fs_prefix + str(self._filepath)                                  │
# │ ❱  87 │   │   return DeltaTable.forPath(_get_spark(), load_path)                                 │
# │    88 │                                                                                          │
# │    89 │   def _save(self, data: None) -> NoReturn:                                               │
# │    90 │   │   raise DatasetError(f"{self.__class__.__name__} is a read only dataset type")       │
# │                                                                                                  │
# │ in forPath:352                                                                                   │
# │                                                                                                  │
# │    349 │   │   jvm: "JVMView" = sparkSession._sc._jvm  # type: ignore[attr-defined]              │
# │    350 │   │   jsparkSession: "JavaObject" = sparkSession._jsparkSession  # type: ignore[attr-d  │
# │    351 │   │                                                                                     │
# │ ❱  352 │   │   jdt = jvm.io.delta.tables.DeltaTable.forPath(jsparkSession, path)                 │
# │    353 │   │   return DeltaTable(sparkSession, jdt)                                              │
# │    354 │                                                                                         │
# │    355 │   @classmethod                                                                          │
# │                                                                                                  │
# │ /home/mark/miniconda3/envs/delta_install/lib/python3.10/site-packages/py4j/java_gateway.py:1321  │
# │ in __call__                                                                                      │
# │                                                                                                  │
# │   1318 │   │   │   proto.END_COMMAND_PART                                                        │
# │   1319 │   │                                                                                     │
# │   1320 │   │   answer = self.gateway_client.send_command(command)                                │
# │ ❱ 1321 │   │   return_value = get_return_value(                                                  │
# │   1322 │   │   │   answer, self.gateway_client, self.target_id, self.name)                       │
# │   1323 │   │                                                                                     │
# │   1324 │   │   for temp_arg in temp_args:                                                        │
# │                                                                                                  │
# │ /home/mark/miniconda3/envs/delta_install/lib/python3.10/site-packages/pyspark/sql/utils.py:117   │
# │ in deco                                                                                          │
# │                                                                                                  │
# │   114 │   │   │   if not isinstance(converted, UnknownException):                                │
# │   115 │   │   │   │   # Hide where the exception came from that shows a non-Pythonic             │
# │   116 │   │   │   │   # JVM exception message.                                                   │
# │ ❱ 117 │   │   │   │   raise converted from None                                                  │
# │   118 │   │   │   else:                                                                          │
# │   119 │   │   │   │   raise                                                                      │
# │   120 │   return deco                                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# AnalysisException: `/home/mark/Documents/Github/kedro-ibis/data/01_raw/yellow_tripdata_2023_01` is not a Delta
# table.
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 df_delta = catalog.load("raw_trips_delta")                                                   │
# │   2                                                                                              │
# │                                                                                                  │
# │ /home/mark/miniconda3/envs/delta_install/lib/python3.10/site-packages/kedro/io/data_catalog.py:4 │
# │ 90 in load                                                                                       │
# │                                                                                                  │
# │   487 │   │   │   extra={"markup": True},                                                        │
# │   488 │   │   )                                                                                  │
# │   489 │   │                                                                                      │
# │ ❱ 490 │   │   result = dataset.load()                                                            │
# │   491 │   │                                                                                      │
# │   492 │   │   return result                                                                      │
# │   493                                                                                            │
# │                                                                                                  │
# │ /home/mark/miniconda3/envs/delta_install/lib/python3.10/site-packages/kedro/io/core.py:195 in    │
# │ load                                                                                             │
# │                                                                                                  │
# │   192 │   │   │   message = (                                                                    │
# │   193 │   │   │   │   f"Failed while loading data from data set {str(self)}.\n{str(exc)}"        │
# │   194 │   │   │   )                                                                              │
# │ ❱ 195 │   │   │   raise DatasetError(message) from exc                                           │
# │   196 │                                                                                          │
# │   197 │   def save(self, data: _DI) -> None:                                                     │
# │   198 │   │   """Saves data by delegation to the provided save method.                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# DatasetError: Failed while loading data from data set
# DeltaTableDataset(filepath=/home/mark/Documents/Github/kedro-ibis/data/01_raw/yellow_tripdata_2023_01, fs_prefix=).
# `/home/mark/Documents/Github/kedro-ibis/data/01_raw/yellow_tripdata_2023_01` is not a Delta table.

# %%
df_spark.write.mode("overwrite").format("delta").save("data/01_raw/trips")
